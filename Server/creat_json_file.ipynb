# %%
import pandas as pd

# %%
models = pd.read_csv('./result/group_by_models.csv')

# %%
models
# Out:
#            category  Unnamed: 1      category.1  \
# 0    GPU并行运算服务器中、低档           3  GPU并行运算服务器中、低档
# 1    GPU并行运算服务器中、低档           2  GPU并行运算服务器中、低档
# 2    GPU并行运算服务器中、低档           8  GPU并行运算服务器中、低档
# 3    GPU并行运算服务器中、低档           6  GPU并行运算服务器中、低档
# 4    GPU并行运算服务器中、低档           7  GPU并行运算服务器中、低档
# 5    GPU并行运算服务器中、低档           5  GPU并行运算服务器中、低档
# 6    GPU并行运算服务器中、低档           0  GPU并行运算服务器中、低档
# 7    GPU并行运算服务器中、低档           4  GPU并行运算服务器中、低档
# 8    GPU并行运算服务器中、低档           1  GPU并行运算服务器中、低档
# 9    GPU并行运算服务器中、低档           9  GPU并行运算服务器中、低档
# 10     GPU并行运算服务器高档          18    GPU并行运算服务器高档
# 11     GPU并行运算服务器高档          13    GPU并行运算服务器高档
# 12     GPU并行运算服务器高档          10    GPU并行运算服务器高档
# 13     GPU并行运算服务器高档          19    GPU并行运算服务器高档
# 14     GPU并行运算服务器高档          15    GPU并行运算服务器高档
# 15     GPU并行运算服务器高档          12    GPU并行运算服务器高档
# 16     GPU并行运算服务器高档          20    GPU并行运算服务器高档
# 17     GPU并行运算服务器高档          16    GPU并行运算服务器高档
# 18     GPU并行运算服务器高档          11    GPU并行运算服务器高档
# 19     GPU并行运算服务器高档          17    GPU并行运算服务器高档
# 20     GPU并行运算服务器高档          14    GPU并行运算服务器高档
# 21         MIC并行服务器          26        MIC并行服务器
# 22         MIC并行服务器          22        MIC并行服务器
# 23         MIC并行服务器          23        MIC并行服务器
# 24         MIC并行服务器          28        MIC并行服务器
# 25         MIC并行服务器          25        MIC并行服务器
# 26         MIC并行服务器          24        MIC并行服务器
# 27         MIC并行服务器          21        MIC并行服务器
# 28         MIC并行服务器          27        MIC并行服务器
# 29          UNIX服务器          30         UNIX服务器
# ..              ...         ...             ...
# 102      机架式服务器中、低档          91      机架式服务器中、低档
# 103      机架式服务器中、低档          99      机架式服务器中、低档
# 104      机架式服务器中、低档         108      机架式服务器中、低档
# 105      机架式服务器中、低档         111      机架式服务器中、低档
# 106      机架式服务器中、低档         103      机架式服务器中、低档
# 107      机架式服务器中、低档          86      机架式服务器中、低档
# 108      机架式服务器中、低档         110      机架式服务器中、低档
# 109      机架式服务器中、低档         102      机架式服务器中、低档
# 110      机架式服务器中、低档          96      机架式服务器中、低档
# 111      机架式服务器中、低档          97      机架式服务器中、低档
# 112      机架式服务器中、低档         115      机架式服务器中、低档
# 113      机架式服务器中、低档         101      机架式服务器中、低档
# 114      机架式服务器中、低档          93      机架式服务器中、低档
# 115      机架式服务器中、低档         114      机架式服务器中、低档
# 116        机架式服务器高档         118        机架式服务器高档
# 117        机架式服务器高档         125        机架式服务器高档
# 118        机架式服务器高档         123        机架式服务器高档
# 119        机架式服务器高档         126        机架式服务器高档
# 120        机架式服务器高档         120        机架式服务器高档
# 121        机架式服务器高档         128        机架式服务器高档
# 122        机架式服务器高档         121        机架式服务器高档
# 123        机架式服务器高档         127        机架式服务器高档
# 124        机架式服务器高档         130        机架式服务器高档
# 125        机架式服务器高档         119        机架式服务器高档
# 126        机架式服务器高档         131        机架式服务器高档
# 127        机架式服务器高档         122        机架式服务器高档
# 128        机架式服务器高档         129        机架式服务器高档
# 129        机架式服务器高档         117        机架式服务器高档
# 130        机架式服务器高档         116        机架式服务器高档
# 131        机架式服务器高档         124        机架式服务器高档
#
#                                           model  total_price  number      prop
# 0                            inspur浪潮, NF8460M4   3908898.00      55  0.039537
# 1                            inspur浪潮, NF5270M4   1444156.00      67  0.014607
# 2                       戴尔, Dell PowerEdge R730    642243.00      27  0.006496
# 3         华为, RH2288H V2+2*E5-2620V2处理器+32GB 内存    593506.20      24  0.006003
# 4                                惠普, ML350 Gen9    374184.00       5  0.003785
# 5                 华三（H3C）, H3C UIS R390 G2【配置升级     85584.00       3  0.000866
# 6                         LTHPC（联泰集群）, LT-7038A     85180.00       7  0.000862
# 7                      华三（H3C）, H3C UIS R390 G2     50000.00       2  0.000506
# 8                         LTHPC（联泰集群）, LT-7048A     26700.00       2  0.000270
# 9                                    曙光, W560-G     19500.00       1  0.000197
# 10                      戴尔, Dell PowerEdge R730   1762234.00      53  0.017824
# 11                            inspur浪潮, TS860G3   1105000.00       3  0.011177
# 12               Lenovo systemX, System x3650M5   1005485.00      31  0.010170
# 13                                  曙光, W580I-G    989475.00      29  0.010008
# 14   华为, RH2288H V3+2*E5-2609V3处理器+64GB DDR4 内存    609554.55      19  0.006165
# 15                           inspur浪潮, NF5288M4    444980.00       6  0.004501
# 16                                   曙光, W780-G    346962.00      10  0.003509
# 17   华为, RH5885H V3+4*E7-4809V3处理器+64GB DDR4 内存    317654.97       3  0.003213
# 18              Oracle（Sun）, PCA compute server    149179.00       1  0.001509
# 19                                  容天, SCS4450    113600.00       2  0.001149
# 20               华三（H3C）, H3C UIS R390 G2【配置升级】     47697.00       1  0.000482
# 21                    戴尔, Dell PowerEdge R730XD   2129929.00      71  0.021543
# 22                           inspur浪潮, NF5280M4   1684700.00      32  0.017040
# 23                           inspur浪潮, NF5568M4    779900.00      11  0.007888
# 24                                超云, R9480 G10    240000.00       2  0.002427
# 25                      戴尔, Dell PowerEdge R430    192288.00       8  0.001945
# 26                     戴尔, Dell PowerEdge C6320    101240.00       4  0.001024
# 27                    LTHPC（联泰集群）, LT-7048GR-TR     97400.00       4  0.000985
# 28                                     曙光, A840     43550.00       1  0.000440
# 29                Lenovo（联想）, ThinkServer RQ940   2886988.00      22  0.029201
# ..                                          ...          ...     ...       ...
# 102              PowerLeader（宝德）, PR2012GS1-CD1    329660.00       7  0.003334
# 103       华为, RH1288 V3+1*E5-2609处理器+8GB DDR4内存    246918.72      13  0.002497
# 104                                    曙光, A620    245320.00      15  0.002481
# 105                               清华同方, 超强TR730    137246.00       9  0.001388
# 106                                思腾合力, IR4200    130760.00       7  0.001323
# 107                       LTHPC（联泰集群）, LT-6028R    120000.00      12  0.001214
# 108                                    汉柏, C640     86000.00       4  0.000870
# 109                                思腾合力, IR2200     71160.00       6  0.000720
# 110                             云海麒麟, YH-5210V3     57500.00       4  0.000582
# 111            华三（H3C）, H3C UIS R190 G2(8LFF主机)     46200.00       2  0.000467
# 112                                  金品, KU2455     26160.00       2  0.000265
# 113                     强氧, 强氧 RS2700 V3/262016     20000.00       1  0.000202
# 114                     ZTE中兴, ZXCLOUD R5300 G3     19057.00       1  0.000193
# 115                                  金品, KU2235     10000.00       1  0.000101
# 116              Lenovo systemX, System x3850X6   7866640.00      79  0.079567
# 117                              惠普, DL580 Gen9   6981569.00      36  0.070615
# 118      华为, RH5885 V3+4*E7-4809处理器+32GB DDR4内存   5212970.65      56  0.052727
# 119                     戴尔, Dell PowerEdge R930   3541433.00      66  0.035820
# 120                          inspur浪潮, NF8480M4   3166896.50      41  0.032032
# 121                                曙光, I840-G20   2262878.00      39  0.022888
# 122                           inspur浪潮, TS860G3   1189800.00       7  0.012034
# 123                                  曙光, I840-G    692025.00      11  0.007000
# 124                               超云, R7410 G10    486200.00       9  0.004918
# 125                    PowerLeader（宝德）, PR4860R    399026.00       4  0.004036
# 126                                  金品, KU4450    380240.00       6  0.003846
# 127                    华三（H3C）, H3C UIS R690 G2    346520.00       4  0.003505
# 128                               清华同方, 超强TR930    303000.00       5  0.003065
# 129                     LTHPC（联泰集群）, LT-8049-TR    266000.00       6  0.002690
# 130                    IBM, Power System S822LC    251998.00       1  0.002549
# 131                                思腾合力, IR4202     66200.00       2  0.000670
#
# [132 rows x 7 columns]

# %%
category = models['category'].tolist()
model = models['model'].tolist()
total_price = models['total_price'].tolist()

# %%
with open('./Demo/models.json', 'w') as w:
    category.append(0)
    t = 0
    w.write('{\n "name": "server",\n "children": [\n')
    for i in range(len(category)-1):
        if category[i+1] != category[i]:
            w.write('  {\n   "name": "' +category[i]+'",\n   "children": [\n')
            for j in range(t,i+1):
                w.write('    {"name": "' + model[j] + '", "size": ' + str(total_price[j]) + '},\n') 
            w.write('   ]\n  },\n')
            t = i+1
    w.write(' ]\n}')
