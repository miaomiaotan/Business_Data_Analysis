# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
China = pd.read_csv('./result/all_sale_info.csv',index_col= None)

# %%
China
# Out:
#            id  category           brand                   type  \
# 0     3921667   塔式服务器高档        inspur浪潮                  P8000
# 1     3921667   塔式服务器高档        inspur浪潮                  P8000
# 2     3921667   塔式服务器高档        inspur浪潮                  P8000
# 3     3921666   塔式服务器高档        inspur浪潮                  P8000
# 4     3921666   塔式服务器高档        inspur浪潮                  P8000
# 5     3921666   塔式服务器高档        inspur浪潮                  P8000
# 6     3921666   塔式服务器高档        inspur浪潮                  P8000
# 7     3921666   塔式服务器高档        inspur浪潮                  P8000
# 8     3921666   塔式服务器高档        inspur浪潮                  P8000
# 9     3921666   塔式服务器高档        inspur浪潮                  P8000
# 10    3921666   塔式服务器高档        inspur浪潮                  P8000
# 11    3921666   塔式服务器高档        inspur浪潮                  P8000
# 12    3921666   塔式服务器高档        inspur浪潮                  P8000
# 13    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 14    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 15    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 16    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 17    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 18    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 19    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 20    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 21    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 22    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 23    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 24    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 25    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 26    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 27    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 28    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# 29    3921329   塔式服务器高档              戴尔    Dell PowerEdge T630
# ...       ...       ...             ...                    ...
# 1043  3921351  MIC并行服务器              戴尔  Dell PowerEdge R730XD
# 1044  3921351  MIC并行服务器              戴尔  Dell PowerEdge R730XD
# 1045  3921351  MIC并行服务器              戴尔  Dell PowerEdge R730XD
# 1046  3921351  MIC并行服务器              戴尔  Dell PowerEdge R730XD
# 1047  3921351  MIC并行服务器              戴尔  Dell PowerEdge R730XD
# 1048  3921351  MIC并行服务器              戴尔  Dell PowerEdge R730XD
# 1049  3921351  MIC并行服务器              戴尔  Dell PowerEdge R730XD
# 1050  3921351  MIC并行服务器              戴尔  Dell PowerEdge R730XD
# 1051  3919372  MIC并行服务器              曙光                   A840
# 1052  3919326  MIC并行服务器     LTHPC（联泰集群）           LT-7048GR-TR
# 1053  3919326  MIC并行服务器     LTHPC（联泰集群）           LT-7048GR-TR
# 1054  3919326  MIC并行服务器     LTHPC（联泰集群）           LT-7048GR-TR
# 1055  3919326  MIC并行服务器     LTHPC（联泰集群）           LT-7048GR-TR
# 1056  3916863  MIC并行服务器              超云              R9480 G10
# 1057  3921485   UNIX服务器            新云东方       NA7822(7822-A1C)
# 1058  3921484   UNIX服务器            新云东方       NA6814(6814-A1C)
# 1059  3921484   UNIX服务器            新云东方       NA6814(6814-A1C)
# 1060  3919375   UNIX服务器              曙光        I980-G10（支持双四路）
# 1061  3918591   UNIX服务器  Lenovo systemX         System x3950X6
# 1062  3918591   UNIX服务器  Lenovo systemX         System x3950X6
# 1063  3917897   UNIX服务器      Lenovo（联想）      ThinkServer RQ940
# 1064  3917897   UNIX服务器      Lenovo（联想）      ThinkServer RQ940
# 1065  3917897   UNIX服务器      Lenovo（联想）      ThinkServer RQ940
# 1066  3917896   UNIX服务器      Lenovo（联想）      ThinkServer RQ940
# 1067  3917896   UNIX服务器      Lenovo（联想）      ThinkServer RQ940
# 1068  3917895   UNIX服务器      Lenovo（联想）      ThinkServer RQ940
# 1069  3917895   UNIX服务器      Lenovo（联想）      ThinkServer RQ940
# 1070  3917895   UNIX服务器      Lenovo（联想）      ThinkServer RQ940
# 1071  3917895   UNIX服务器      Lenovo（联想）      ThinkServer RQ940
# 1072  3917895   UNIX服务器      Lenovo（联想）      ThinkServer RQ940
#
#                                model                   buyer  number  \
# 0                    inspur浪潮, P8000      黄河水利委员会三门峡库区水文水资源局       1
# 1                    inspur浪潮, P8000                    同济大学       1
# 2                    inspur浪潮, P8000  水利部交通运输部国家能源局南京水利科学研究院       1
# 3                    inspur浪潮, P8000  水利部交通运输部国家能源局南京水利科学研究院       1
# 4                    inspur浪潮, P8000                 北京外国语大学       1
# 5                    inspur浪潮, P8000                北京航空航天大学       1
# 6                    inspur浪潮, P8000                  北京交通大学       1
# 7                    inspur浪潮, P8000                  中国矿业大学       1
# 8                    inspur浪潮, P8000                  中国矿业大学       1
# 9                    inspur浪潮, P8000               长江武汉航道工程局       1
# 10                   inspur浪潮, P8000              华北电力大学（保定）       1
# 11                   inspur浪潮, P8000                住房和城乡建设部       1
# 12                   inspur浪潮, P8000  水利部交通运输部国家能源局南京水利科学研究院       2
# 13           戴尔, Dell PowerEdge T630        中国水产科学研究院黄海水产研究所       1
# 14           戴尔, Dell PowerEdge T630         中国科学院地理科学与资源研究所       1
# 15           戴尔, Dell PowerEdge T630                  大连海事大学       2
# 16           戴尔, Dell PowerEdge T630            中国科学院信息工程研究所       1
# 17           戴尔, Dell PowerEdge T630                    晋中学院       1
# 18           戴尔, Dell PowerEdge T630                    浙江大学       1
# 19           戴尔, Dell PowerEdge T630       中华人民共和国江门出入境检验检疫局       1
# 20           戴尔, Dell PowerEdge T630                  西南交通大学       1
# 21           戴尔, Dell PowerEdge T630              中国科学院国家天文台       2
# 22           戴尔, Dell PowerEdge T630                 北京协和医学院       1
# 23           戴尔, Dell PowerEdge T630          国家新闻出版广电总局五六四台       1
# 24           戴尔, Dell PowerEdge T630          中国科学院深圳先进技术研究院       1
# 25           戴尔, Dell PowerEdge T630                    浙江大学       1
# 26           戴尔, Dell PowerEdge T630                    浙江大学       1
# 27           戴尔, Dell PowerEdge T630                  中国矿业大学       1
# 28           戴尔, Dell PowerEdge T630               东北大学秦皇岛分校       2
# 29           戴尔, Dell PowerEdge T630                  华北电力大学       2
# ...                              ...                     ...     ...
# 1043       戴尔, Dell PowerEdge R730XD            中国科学院计算技术研究所      13
# 1044       戴尔, Dell PowerEdge R730XD            中国科学院计算技术研究所      12
# 1045       戴尔, Dell PowerEdge R730XD               中国测绘科学研究院       1
# 1046       戴尔, Dell PowerEdge R730XD            中国科学院信息工程研究所       6
# 1047       戴尔, Dell PowerEdge R730XD            中国科学院信息工程研究所       4
# 1048       戴尔, Dell PowerEdge R730XD                  北京邮电大学       2
# 1049       戴尔, Dell PowerEdge R730XD          中国科学院计算机网络信息中心       6
# 1050       戴尔, Dell PowerEdge R730XD                中国科学技术大学       1
# 1051                        曙光, A840                    浙江大学       1
# 1052       LTHPC（联泰集群）, LT-7048GR-TR                  北京邮电大学       1
# 1053       LTHPC（联泰集群）, LT-7048GR-TR             中国科学院自动化研究所       1
# 1054       LTHPC（联泰集群）, LT-7048GR-TR              中国科学院力学研究所       1
# 1055       LTHPC（联泰集群）, LT-7048GR-TR          中国科学院深圳先进技术研究院       1
# 1056                   超云, R9480 G10          中国科学院深圳先进技术研究院       2
# 1057          新云东方, NA7822(7822-A1C)                  北京交通大学       1
# 1058          新云东方, NA6814(6814-A1C)              国家基础地理信息中心       2
# 1059          新云东方, NA6814(6814-A1C)            工业和信息化部电信研究院       2
# 1060             曙光, I980-G10（支持双四路）            中华全国总工会网络工作部       2
# 1061  Lenovo systemX, System x3950X6          中国科学院计算机网络信息中心       2
# 1062  Lenovo systemX, System x3950X6                中国科学技术大学       1
# 1063   Lenovo（联想）, ThinkServer RQ940          湖北省气象信息与技术保障中心       1
# 1064   Lenovo（联想）, ThinkServer RQ940                  太原市气象局       1
# 1065   Lenovo（联想）, ThinkServer RQ940            中国人民银行金融信息中心       8
# 1066   Lenovo（联想）, ThinkServer RQ940               科技部科技评估中心       1
# 1067   Lenovo（联想）, ThinkServer RQ940             工业和信息化部信息中心       2
# 1068   Lenovo（联想）, ThinkServer RQ940                北京一三一八单位       2
# 1069   Lenovo（联想）, ThinkServer RQ940                北京一三一八单位       2
# 1070   Lenovo（联想）, ThinkServer RQ940                北京一三一八单位       2
# 1071   Lenovo（联想）, ThinkServer RQ940                北京一三一八单位       2
# 1072   Lenovo（联想）, ThinkServer RQ940                北京一三一八单位       1
#
#          price               seller        date      time  total_price
# 0      34500.0          郑州嘉运达科技有限公司  2016-06-13  08:51:36      34500.0
# 1      36950.0         上海华胄网络科技有限公司  2016-05-18  16:17:59      36950.0
# 2      34890.0         南京柏华信息科技有限公司  2016-03-30  11:47:34      34890.0
# 3      46300.0         江苏元德信息技术有限公司  2016-07-12  15:21:19      46300.0
# 4      48152.5         北京博略顺和科技有限公司  2016-06-20  16:29:31      48152.5
# 5      48152.5       北京众和永业科技发展有限公司  2016-05-12  17:06:20      48152.5
# 6      48152.5       北京华航创新科技有限责任公司  2016-05-03  14:46:14      48152.5
# 7      48000.0         南京柏华信息科技有限公司  2016-04-12  15:55:49      48000.0
# 8      31000.0         南京柏华信息科技有限公司  2016-04-12  15:55:10      31000.0
# 9      48152.5           武汉英信科技有限公司  2016-04-11  11:43:12      48152.5
# 10     48152.5       北京众和永业科技发展有限公司  2016-03-29  15:34:10      48152.5
# 11     48152.5           北京优兆科技有限公司  2016-03-02  10:11:42      48152.5
# 12     41860.0         南京柏华信息科技有限公司  2016-01-24  17:09:02      83720.0
# 13     24954.0       青岛天业人勤电子科技有限公司  2016-08-05  10:52:16      24954.0
# 14     24954.0       北京网信未来信息技术有限公司  2016-07-28  09:16:11      24954.0
# 15     24954.0       大连翰林数码网络科技有限公司  2016-07-14  16:06:57      49908.0
# 16     24954.0       北京核聚瑞增系统科技有限公司  2016-06-22  09:10:47      24954.0
# 17     24954.0          山西指北针科技有限公司  2016-06-20  10:24:00      24954.0
# 18     24954.0         浙江同力信息科技有限公司  2016-06-16  11:31:42      24954.0
# 19     24954.0       江门市江海区金辉办公设备总汇  2016-06-14  17:59:45      24954.0
# 20     24954.0  北京网信未来信息技术有限公司成都分公司  2016-06-14  10:03:45      24954.0
# 21     24954.0       北京友邦佳通电子科技有限公司  2016-05-19  11:25:14      49908.0
# 22     24954.0           北京康邦科技有限公司  2016-05-18  16:58:04      24954.0
# 23     24954.0       北京趋势未来科技发展有限公司  2016-05-16  10:12:36      24954.0
# 24     24954.0     深圳市长城网信息科技股份有限公司  2016-05-09  16:56:38      24954.0
# 25     24954.0         浙江同力信息科技有限公司  2016-05-04  15:26:22      24954.0
# 26     24954.0         浙江同力信息科技有限公司  2016-05-04  14:55:06      24954.0
# 27     24954.0           徐州程辉科技有限公司  2016-04-28  08:56:21      24954.0
# 28     24954.0       北京众和永业科技发展有限公司  2016-04-27  09:42:33      49908.0
# 29     24954.0       北京友邦佳通电子科技有限公司  2016-04-23  10:03:18      49908.0
# ...        ...                  ...         ...       ...          ...
# 1043   29999.0         北京迅驰动力科技有限公司  2016-06-29  10:12:47     389987.0
# 1044   29999.0         北京迅驰动力科技有限公司  2016-06-29  10:12:21     359988.0
# 1045   29999.0         北京胜创致远科技有限公司  2016-06-21  14:53:50      29999.0
# 1046   29999.0         北京瑞昌恒业科技有限公司  2016-06-08  10:36:29     179994.0
# 1047   29999.0       北京趋势未来科技发展有限公司  2016-06-08  10:34:22     119996.0
# 1048   29999.0         北京华建德泰商贸有限公司  2016-05-13  18:03:38      59998.0
# 1049   29999.0       北京趋势未来科技发展有限公司  2016-05-12  09:54:01     179994.0
# 1050   29999.0        合肥佳思特信息技术有限公司  2016-05-05  16:03:06      29999.0
# 1051   43550.0         浙江同力信息科技有限公司  2016-05-11  11:47:25      43550.0
# 1052   23600.0     联泰集群（北京）科技有限责任公司  2016-07-11  15:40:21      23600.0
# 1053   24600.0     联泰集群（北京）科技有限责任公司  2016-06-27  13:16:07      24600.0
# 1054   24600.0     联泰集群（北京）科技有限责任公司  2016-06-22  16:59:18      24600.0
# 1055   24600.0         东莞超博电子科技有限公司  2016-04-27  16:45:50      24600.0
# 1056  120000.0         北京天地超云科技有限公司  2016-07-21  11:46:47     240000.0
# 1057  734054.0       北京友邦佳通电子科技有限公司  2016-05-30  10:40:36     734054.0
# 1058  257075.0       北京北方怡合信息技术有限公司  2016-05-25  15:01:03     514150.0
# 1059  257075.0           北京优兆科技有限公司  2016-05-18  15:28:51     514150.0
# 1060  120430.0       北京俊轶时代电子科技有限公司  2016-08-18  14:45:57     240860.0
# 1061  309362.0     北京华诚联合设备安装工程有限公司  2016-07-14  16:12:36     618724.0
# 1062  309362.0       安徽时代中佳科贸有限责任公司  2016-07-04  15:05:13     309362.0
# 1063  106918.0           武汉联钢科技有限公司  2016-06-15  15:09:32     106918.0
# 1064  106918.0         山西世纪创想电子有限公司  2016-06-12  18:06:08     106918.0
# 1065  106918.0      北京嘉运达科技开发股份有限公司  2016-05-25  09:28:40     855344.0
# 1066  105219.0         北京银联合力科技有限公司  2016-08-18  11:19:16     105219.0
# 1067  110757.0      北京嘉运达科技开发股份有限公司  2016-05-20  13:52:45     221514.0
# 1068  165675.0         北京奇点宏业科技有限公司  2016-05-16  11:04:13     331350.0
# 1069  165675.0         北京奇点宏业科技有限公司  2016-05-10  10:46:26     331350.0
# 1070  165675.0         北京奇点宏业科技有限公司  2016-04-05  10:22:48     331350.0
# 1071  165675.0         北京奇点宏业科技有限公司  2016-04-05  10:22:17     331350.0
# 1072  165675.0         北京奇点宏业科技有限公司  2016-03-25  14:11:37     165675.0
#
# [1073 rows x 12 columns]

# %%
#China['prop'] = China['total_price']/China.total_price.sum()

# %%
China['total_price'].sum()
# Out:
# 98867753.56000003

# %% [markdown]
# # 1.group by category

# %%
categories = China.groupby('category', as_index=False).total_price.sum().sort_values('total_price',ascending=False)

# %%
categories['prop'] = categories['total_price']/categories.total_price.sum()

# %%
categories
# Out:
#           category  total_price      prop
# 11        机架式服务器高档  33413396.15  0.337961
# 10      机架式服务器中、低档  17059720.58  0.172551
# 0   GPU并行运算服务器中、低档   7229951.20  0.073127
# 1     GPU并行运算服务器高档   6891821.52  0.069707
# 3          UNIX服务器   5818288.00  0.058849
# 9          塔式服务器高档   5810033.00  0.058766
# 2         MIC并行服务器   5269007.00  0.053293
# 4          刀片服务器中档   4918526.64  0.049749
# 6          刀片服务器高档   4010697.76  0.040566
# 5          刀片服务器低档   3825200.71  0.038690
# 7          塔式服务器中档   2697574.00  0.027285
# 8          塔式服务器低档   1923537.00  0.019456

# %%
categories.to_csv('./result/group_by_categories.csv' , index_col= None)

# %% [markdown]
# # 2.group by model

# %%
def sort_models(group):
    return group.sort_values('total_price',ascending=False)

# %%
models = China.groupby(['category','model'],as_index=False).total_price.sum()

# %%
models
# Out:
#            category                                       model  total_price
# 0    GPU并行运算服务器中、低档                       LTHPC（联泰集群）, LT-7038A     85180.00
# 1    GPU并行运算服务器中、低档                       LTHPC（联泰集群）, LT-7048A     26700.00
# 2    GPU并行运算服务器中、低档                          inspur浪潮, NF5270M4   1444156.00
# 3    GPU并行运算服务器中、低档                          inspur浪潮, NF8460M4   3908898.00
# 4    GPU并行运算服务器中、低档                    华三（H3C）, H3C UIS R390 G2     50000.00
# 5    GPU并行运算服务器中、低档               华三（H3C）, H3C UIS R390 G2【配置升级     85584.00
# 6    GPU并行运算服务器中、低档       华为, RH2288H V2+2*E5-2620V2处理器+32GB 内存    593506.20
# 7    GPU并行运算服务器中、低档                              惠普, ML350 Gen9    374184.00
# 8    GPU并行运算服务器中、低档                     戴尔, Dell PowerEdge R730    642243.00
# 9    GPU并行运算服务器中、低档                                  曙光, W560-G     19500.00
# 10     GPU并行运算服务器高档              Lenovo systemX, System x3650M5   1005485.00
# 11     GPU并行运算服务器高档             Oracle（Sun）, PCA compute server    149179.00
# 12     GPU并行运算服务器高档                          inspur浪潮, NF5288M4    444980.00
# 13     GPU并行运算服务器高档                           inspur浪潮, TS860G3   1105000.00
# 14     GPU并行运算服务器高档              华三（H3C）, H3C UIS R390 G2【配置升级】     47697.00
# 15     GPU并行运算服务器高档  华为, RH2288H V3+2*E5-2609V3处理器+64GB DDR4 内存    609554.55
# 16     GPU并行运算服务器高档  华为, RH5885H V3+4*E7-4809V3处理器+64GB DDR4 内存    317654.97
# 17     GPU并行运算服务器高档                                 容天, SCS4450    113600.00
# 18     GPU并行运算服务器高档                     戴尔, Dell PowerEdge R730   1762234.00
# 19     GPU并行运算服务器高档                                 曙光, W580I-G    989475.00
# 20     GPU并行运算服务器高档                                  曙光, W780-G    346962.00
# 21         MIC并行服务器                   LTHPC（联泰集群）, LT-7048GR-TR     97400.00
# 22         MIC并行服务器                          inspur浪潮, NF5280M4   1684700.00
# 23         MIC并行服务器                          inspur浪潮, NF5568M4    779900.00
# 24         MIC并行服务器                    戴尔, Dell PowerEdge C6320    101240.00
# 25         MIC并行服务器                     戴尔, Dell PowerEdge R430    192288.00
# 26         MIC并行服务器                   戴尔, Dell PowerEdge R730XD   2129929.00
# 27         MIC并行服务器                                    曙光, A840     43550.00
# 28         MIC并行服务器                               超云, R9480 G10    240000.00
# 29          UNIX服务器              Lenovo systemX, System x3950X6    928086.00
# ..              ...                                         ...          ...
# 102      机架式服务器中、低档                                思腾合力, IR2200     71160.00
# 103      机架式服务器中、低档                                思腾合力, IR4200    130760.00
# 104      机架式服务器中、低档                              惠普, DL360 Gen9    505292.00
# 105      机架式服务器中、低档                              惠普, DL380 Gen9   1539585.00
# 106      机架式服务器中、低档                     戴尔, Dell PowerEdge R630    744172.00
# 107      机架式服务器中、低档                     戴尔, Dell PowerEdge R730    472050.00
# 108      机架式服务器中、低档                                    曙光, A620    245320.00
# 109      机架式服务器中、低档                                  曙光, I620-G   1134768.00
# 110      机架式服务器中、低档                                    汉柏, C640     86000.00
# 111      机架式服务器中、低档                               清华同方, 超强TR730    137246.00
# 112      机架式服务器中、低档                               超云, R5210 G10    860338.00
# 113      机架式服务器中、低档                               超云, R6240 G10    504677.00
# 114      机架式服务器中、低档                                  金品, KU2235     10000.00
# 115      机架式服务器中、低档                                  金品, KU2455     26160.00
# 116        机架式服务器高档                    IBM, Power System S822LC    251998.00
# 117        机架式服务器高档                     LTHPC（联泰集群）, LT-8049-TR    266000.00
# 118        机架式服务器高档              Lenovo systemX, System x3850X6   7866640.00
# 119        机架式服务器高档                    PowerLeader（宝德）, PR4860R    399026.00
# 120        机架式服务器高档                          inspur浪潮, NF8480M4   3166896.50
# 121        机架式服务器高档                           inspur浪潮, TS860G3   1189800.00
# 122        机架式服务器高档                    华三（H3C）, H3C UIS R690 G2    346520.00
# 123        机架式服务器高档      华为, RH5885 V3+4*E7-4809处理器+32GB DDR4内存   5212970.65
# 124        机架式服务器高档                                思腾合力, IR4202     66200.00
# 125        机架式服务器高档                              惠普, DL580 Gen9   6981569.00
# 126        机架式服务器高档                     戴尔, Dell PowerEdge R930   3541433.00
# 127        机架式服务器高档                                  曙光, I840-G    692025.00
# 128        机架式服务器高档                                曙光, I840-G20   2262878.00
# 129        机架式服务器高档                               清华同方, 超强TR930    303000.00
# 130        机架式服务器高档                               超云, R7410 G10    486200.00
# 131        机架式服务器高档                                  金品, KU4450    380240.00
#
# [132 rows x 3 columns]

# %%
models['number'] = China.groupby(['category','model'],as_index=False).number.sum()['number']

# %%
models['prop'] = models['total_price']/models.total_price.sum()

# %%
models
# Out:
#            category                                       model  total_price  \
# 0    GPU并行运算服务器中、低档                       LTHPC（联泰集群）, LT-7038A     85180.00
# 1    GPU并行运算服务器中、低档                       LTHPC（联泰集群）, LT-7048A     26700.00
# 2    GPU并行运算服务器中、低档                          inspur浪潮, NF5270M4   1444156.00
# 3    GPU并行运算服务器中、低档                          inspur浪潮, NF8460M4   3908898.00
# 4    GPU并行运算服务器中、低档                    华三（H3C）, H3C UIS R390 G2     50000.00
# 5    GPU并行运算服务器中、低档               华三（H3C）, H3C UIS R390 G2【配置升级     85584.00
# 6    GPU并行运算服务器中、低档       华为, RH2288H V2+2*E5-2620V2处理器+32GB 内存    593506.20
# 7    GPU并行运算服务器中、低档                              惠普, ML350 Gen9    374184.00
# 8    GPU并行运算服务器中、低档                     戴尔, Dell PowerEdge R730    642243.00
# 9    GPU并行运算服务器中、低档                                  曙光, W560-G     19500.00
# 10     GPU并行运算服务器高档              Lenovo systemX, System x3650M5   1005485.00
# 11     GPU并行运算服务器高档             Oracle（Sun）, PCA compute server    149179.00
# 12     GPU并行运算服务器高档                          inspur浪潮, NF5288M4    444980.00
# 13     GPU并行运算服务器高档                           inspur浪潮, TS860G3   1105000.00
# 14     GPU并行运算服务器高档              华三（H3C）, H3C UIS R390 G2【配置升级】     47697.00
# 15     GPU并行运算服务器高档  华为, RH2288H V3+2*E5-2609V3处理器+64GB DDR4 内存    609554.55
# 16     GPU并行运算服务器高档  华为, RH5885H V3+4*E7-4809V3处理器+64GB DDR4 内存    317654.97
# 17     GPU并行运算服务器高档                                 容天, SCS4450    113600.00
# 18     GPU并行运算服务器高档                     戴尔, Dell PowerEdge R730   1762234.00
# 19     GPU并行运算服务器高档                                 曙光, W580I-G    989475.00
# 20     GPU并行运算服务器高档                                  曙光, W780-G    346962.00
# 21         MIC并行服务器                   LTHPC（联泰集群）, LT-7048GR-TR     97400.00
# 22         MIC并行服务器                          inspur浪潮, NF5280M4   1684700.00
# 23         MIC并行服务器                          inspur浪潮, NF5568M4    779900.00
# 24         MIC并行服务器                    戴尔, Dell PowerEdge C6320    101240.00
# 25         MIC并行服务器                     戴尔, Dell PowerEdge R430    192288.00
# 26         MIC并行服务器                   戴尔, Dell PowerEdge R730XD   2129929.00
# 27         MIC并行服务器                                    曙光, A840     43550.00
# 28         MIC并行服务器                               超云, R9480 G10    240000.00
# 29          UNIX服务器              Lenovo systemX, System x3950X6    928086.00
# ..              ...                                         ...          ...
# 102      机架式服务器中、低档                                思腾合力, IR2200     71160.00
# 103      机架式服务器中、低档                                思腾合力, IR4200    130760.00
# 104      机架式服务器中、低档                              惠普, DL360 Gen9    505292.00
# 105      机架式服务器中、低档                              惠普, DL380 Gen9   1539585.00
# 106      机架式服务器中、低档                     戴尔, Dell PowerEdge R630    744172.00
# 107      机架式服务器中、低档                     戴尔, Dell PowerEdge R730    472050.00
# 108      机架式服务器中、低档                                    曙光, A620    245320.00
# 109      机架式服务器中、低档                                  曙光, I620-G   1134768.00
# 110      机架式服务器中、低档                                    汉柏, C640     86000.00
# 111      机架式服务器中、低档                               清华同方, 超强TR730    137246.00
# 112      机架式服务器中、低档                               超云, R5210 G10    860338.00
# 113      机架式服务器中、低档                               超云, R6240 G10    504677.00
# 114      机架式服务器中、低档                                  金品, KU2235     10000.00
# 115      机架式服务器中、低档                                  金品, KU2455     26160.00
# 116        机架式服务器高档                    IBM, Power System S822LC    251998.00
# 117        机架式服务器高档                     LTHPC（联泰集群）, LT-8049-TR    266000.00
# 118        机架式服务器高档              Lenovo systemX, System x3850X6   7866640.00
# 119        机架式服务器高档                    PowerLeader（宝德）, PR4860R    399026.00
# 120        机架式服务器高档                          inspur浪潮, NF8480M4   3166896.50
# 121        机架式服务器高档                           inspur浪潮, TS860G3   1189800.00
# 122        机架式服务器高档                    华三（H3C）, H3C UIS R690 G2    346520.00
# 123        机架式服务器高档      华为, RH5885 V3+4*E7-4809处理器+32GB DDR4内存   5212970.65
# 124        机架式服务器高档                                思腾合力, IR4202     66200.00
# 125        机架式服务器高档                              惠普, DL580 Gen9   6981569.00
# 126        机架式服务器高档                     戴尔, Dell PowerEdge R930   3541433.00
# 127        机架式服务器高档                                  曙光, I840-G    692025.00
# 128        机架式服务器高档                                曙光, I840-G20   2262878.00
# 129        机架式服务器高档                               清华同方, 超强TR930    303000.00
# 130        机架式服务器高档                               超云, R7410 G10    486200.00
# 131        机架式服务器高档                                  金品, KU4450    380240.00
#
#      number      prop
# 0         7  0.000862
# 1         2  0.000270
# 2        67  0.014607
# 3        55  0.039537
# 4         2  0.000506
# 5         3  0.000866
# 6        24  0.006003
# 7         5  0.003785
# 8        27  0.006496
# 9         1  0.000197
# 10       31  0.010170
# 11        1  0.001509
# 12        6  0.004501
# 13        3  0.011177
# 14        1  0.000482
# 15       19  0.006165
# 16        3  0.003213
# 17        2  0.001149
# 18       53  0.017824
# 19       29  0.010008
# 20       10  0.003509
# 21        4  0.000985
# 22       32  0.017040
# 23       11  0.007888
# 24        4  0.001024
# 25        8  0.001945
# 26       71  0.021543
# 27        1  0.000440
# 28        2  0.002427
# 29        3  0.009387
# ..      ...       ...
# 102       6  0.000720
# 103       7  0.001323
# 104      21  0.005111
# 105      56  0.015572
# 106      44  0.007527
# 107      30  0.004775
# 108      15  0.002481
# 109      66  0.011478
# 110       4  0.000870
# 111       9  0.001388
# 112      46  0.008702
# 113       7  0.005105
# 114       1  0.000101
# 115       2  0.000265
# 116       1  0.002549
# 117       6  0.002690
# 118      79  0.079567
# 119       4  0.004036
# 120      41  0.032032
# 121       7  0.012034
# 122       4  0.003505
# 123      56  0.052727
# 124       2  0.000670
# 125      36  0.070615
# 126      66  0.035820
# 127      11  0.007000
# 128      39  0.022888
# 129       5  0.003065
# 130       9  0.004918
# 131       6  0.003846
#
# [132 rows x 5 columns]

# %%
models = models.groupby(['category']).apply(sort_models)

# %%
models
# Out:
#                           category  \
# category
# GPU并行运算服务器中、低档 3    GPU并行运算服务器中、低档
#                2    GPU并行运算服务器中、低档
#                8    GPU并行运算服务器中、低档
#                6    GPU并行运算服务器中、低档
#                7    GPU并行运算服务器中、低档
#                5    GPU并行运算服务器中、低档
#                0    GPU并行运算服务器中、低档
#                4    GPU并行运算服务器中、低档
#                1    GPU并行运算服务器中、低档
#                9    GPU并行运算服务器中、低档
# GPU并行运算服务器高档   18     GPU并行运算服务器高档
#                13     GPU并行运算服务器高档
#                10     GPU并行运算服务器高档
#                19     GPU并行运算服务器高档
#                15     GPU并行运算服务器高档
#                12     GPU并行运算服务器高档
#                20     GPU并行运算服务器高档
#                16     GPU并行运算服务器高档
#                11     GPU并行运算服务器高档
#                17     GPU并行运算服务器高档
#                14     GPU并行运算服务器高档
# MIC并行服务器       26         MIC并行服务器
#                22         MIC并行服务器
#                23         MIC并行服务器
#                28         MIC并行服务器
#                25         MIC并行服务器
#                24         MIC并行服务器
#                21         MIC并行服务器
#                27         MIC并行服务器
# UNIX服务器        30          UNIX服务器
# ...                            ...
# 机架式服务器中、低档     91       机架式服务器中、低档
#                99       机架式服务器中、低档
#                108      机架式服务器中、低档
#                111      机架式服务器中、低档
#                103      机架式服务器中、低档
#                86       机架式服务器中、低档
#                110      机架式服务器中、低档
#                102      机架式服务器中、低档
#                96       机架式服务器中、低档
#                97       机架式服务器中、低档
#                115      机架式服务器中、低档
#                101      机架式服务器中、低档
#                93       机架式服务器中、低档
#                114      机架式服务器中、低档
# 机架式服务器高档       118        机架式服务器高档
#                125        机架式服务器高档
#                123        机架式服务器高档
#                126        机架式服务器高档
#                120        机架式服务器高档
#                128        机架式服务器高档
#                121        机架式服务器高档
#                127        机架式服务器高档
#                130        机架式服务器高档
#                119        机架式服务器高档
#                131        机架式服务器高档
#                122        机架式服务器高档
#                129        机架式服务器高档
#                117        机架式服务器高档
#                116        机架式服务器高档
#                124        机架式服务器高档
#
#                                                          model  total_price  \
# category
# GPU并行运算服务器中、低档 3                            inspur浪潮, NF8460M4   3908898.00
#                2                            inspur浪潮, NF5270M4   1444156.00
#                8                       戴尔, Dell PowerEdge R730    642243.00
#                6         华为, RH2288H V2+2*E5-2620V2处理器+32GB 内存    593506.20
#                7                                惠普, ML350 Gen9    374184.00
#                5                 华三（H3C）, H3C UIS R390 G2【配置升级     85584.00
#                0                         LTHPC（联泰集群）, LT-7038A     85180.00
#                4                      华三（H3C）, H3C UIS R390 G2     50000.00
#                1                         LTHPC（联泰集群）, LT-7048A     26700.00
#                9                                    曙光, W560-G     19500.00
# GPU并行运算服务器高档   18                      戴尔, Dell PowerEdge R730   1762234.00
#                13                            inspur浪潮, TS860G3   1105000.00
#                10               Lenovo systemX, System x3650M5   1005485.00
#                19                                  曙光, W580I-G    989475.00
#                15   华为, RH2288H V3+2*E5-2609V3处理器+64GB DDR4 内存    609554.55
#                12                           inspur浪潮, NF5288M4    444980.00
#                20                                   曙光, W780-G    346962.00
#                16   华为, RH5885H V3+4*E7-4809V3处理器+64GB DDR4 内存    317654.97
#                11              Oracle（Sun）, PCA compute server    149179.00
#                17                                  容天, SCS4450    113600.00
#                14               华三（H3C）, H3C UIS R390 G2【配置升级】     47697.00
# MIC并行服务器       26                    戴尔, Dell PowerEdge R730XD   2129929.00
#                22                           inspur浪潮, NF5280M4   1684700.00
#                23                           inspur浪潮, NF5568M4    779900.00
#                28                                超云, R9480 G10    240000.00
#                25                      戴尔, Dell PowerEdge R430    192288.00
#                24                     戴尔, Dell PowerEdge C6320    101240.00
#                21                    LTHPC（联泰集群）, LT-7048GR-TR     97400.00
#                27                                     曙光, A840     43550.00
# UNIX服务器        30                Lenovo（联想）, ThinkServer RQ940   2886988.00
# ...                                                        ...          ...
# 机架式服务器中、低档     91               PowerLeader（宝德）, PR2012GS1-CD1    329660.00
#                99        华为, RH1288 V3+1*E5-2609处理器+8GB DDR4内存    246918.72
#                108                                    曙光, A620    245320.00
#                111                               清华同方, 超强TR730    137246.00
#                103                                思腾合力, IR4200    130760.00
#                86                        LTHPC（联泰集群）, LT-6028R    120000.00
#                110                                    汉柏, C640     86000.00
#                102                                思腾合力, IR2200     71160.00
#                96                              云海麒麟, YH-5210V3     57500.00
#                97             华三（H3C）, H3C UIS R190 G2(8LFF主机)     46200.00
#                115                                  金品, KU2455     26160.00
#                101                     强氧, 强氧 RS2700 V3/262016     20000.00
#                93                      ZTE中兴, ZXCLOUD R5300 G3     19057.00
#                114                                  金品, KU2235     10000.00
# 机架式服务器高档       118              Lenovo systemX, System x3850X6   7866640.00
#                125                              惠普, DL580 Gen9   6981569.00
#                123      华为, RH5885 V3+4*E7-4809处理器+32GB DDR4内存   5212970.65
#                126                     戴尔, Dell PowerEdge R930   3541433.00
#                120                          inspur浪潮, NF8480M4   3166896.50
#                128                                曙光, I840-G20   2262878.00
#                121                           inspur浪潮, TS860G3   1189800.00
#                127                                  曙光, I840-G    692025.00
#                130                               超云, R7410 G10    486200.00
#                119                    PowerLeader（宝德）, PR4860R    399026.00
#                131                                  金品, KU4450    380240.00
#                122                    华三（H3C）, H3C UIS R690 G2    346520.00
#                129                               清华同方, 超强TR930    303000.00
#                117                     LTHPC（联泰集群）, LT-8049-TR    266000.00
#                116                    IBM, Power System S822LC    251998.00
#                124                                思腾合力, IR4202     66200.00
#
#                     number      prop
# category
# GPU并行运算服务器中、低档 3        55  0.039537
#                2        67  0.014607
#                8        27  0.006496
#                6        24  0.006003
#                7         5  0.003785
#                5         3  0.000866
#                0         7  0.000862
#                4         2  0.000506
#                1         2  0.000270
#                9         1  0.000197
# GPU并行运算服务器高档   18       53  0.017824
#                13        3  0.011177
#                10       31  0.010170
#                19       29  0.010008
#                15       19  0.006165
#                12        6  0.004501
#                20       10  0.003509
#                16        3  0.003213
#                11        1  0.001509
#                17        2  0.001149
#                14        1  0.000482
# MIC并行服务器       26       71  0.021543
#                22       32  0.017040
#                23       11  0.007888
#                28        2  0.002427
#                25        8  0.001945
#                24        4  0.001024
#                21        4  0.000985
#                27        1  0.000440
# UNIX服务器        30       22  0.029201
# ...                    ...       ...
# 机架式服务器中、低档     91        7  0.003334
#                99       13  0.002497
#                108      15  0.002481
#                111       9  0.001388
#                103       7  0.001323
#                86       12  0.001214
#                110       4  0.000870
#                102       6  0.000720
#                96        4  0.000582
#                97        2  0.000467
#                115       2  0.000265
#                101       1  0.000202
#                93        1  0.000193
#                114       1  0.000101
# 机架式服务器高档       118      79  0.079567
#                125      36  0.070615
#                123      56  0.052727
#                126      66  0.035820
#                120      41  0.032032
#                128      39  0.022888
#                121       7  0.012034
#                127      11  0.007000
#                130       9  0.004918
#                119       4  0.004036
#                131       6  0.003846
#                122       4  0.003505
#                129       5  0.003065
#                117       6  0.002690
#                116       1  0.002549
#                124       2  0.000670
#
# [132 rows x 5 columns]

# %%
models.to_csv('./result/group_by_models.csv' , index_col= None)

# %% [markdown]
# # 2.5 models prop >= 0.015

# %%
prop_0015 = models[models['prop'] >= 0.015]

# %%
prop_0015
# Out:
#                           category                                     model  \
# category
# GPU并行运算服务器中、低档 3    GPU并行运算服务器中、低档                        inspur浪潮, NF8460M4
# GPU并行运算服务器高档   18     GPU并行运算服务器高档                   戴尔, Dell PowerEdge R730
# MIC并行服务器       26         MIC并行服务器                 戴尔, Dell PowerEdge R730XD
#                22         MIC并行服务器                        inspur浪潮, NF5280M4
# UNIX服务器        30          UNIX服务器             Lenovo（联想）, ThinkServer RQ940
# 刀片服务器中档        34          刀片服务器中档        Lenovo systemX, Flex system x240M5
#                41          刀片服务器中档                   戴尔, Dell PowerEdge M630
# 塔式服务器高档        81          塔式服务器高档                   戴尔, Dell PowerEdge T630
# 机架式服务器中、低档     100      机架式服务器中、低档  华为, RH2288 V3+2*E5-2609V3处理器+16GB DDR4内存
#                94       机架式服务器中、低档                        inspur浪潮, NF5170M4
#                90       机架式服务器中、低档             Lenovo（联想）, ThinkServer RD650
#                105      机架式服务器中、低档                            惠普, DL380 Gen9
# 机架式服务器高档       118        机架式服务器高档            Lenovo systemX, System x3850X6
#                125        机架式服务器高档                            惠普, DL580 Gen9
#                123        机架式服务器高档    华为, RH5885 V3+4*E7-4809处理器+32GB DDR4内存
#                126        机架式服务器高档                   戴尔, Dell PowerEdge R930
#                120        机架式服务器高档                        inspur浪潮, NF8480M4
#                128        机架式服务器高档                              曙光, I840-G20
#
#                     total_price  number      prop
# category
# GPU并行运算服务器中、低档 3     3908898.00      55  0.039537
# GPU并行运算服务器高档   18    1762234.00      53  0.017824
# MIC并行服务器       26    2129929.00      71  0.021543
#                22    1684700.00      32  0.017040
# UNIX服务器        30    2886988.00      22  0.029201
# 刀片服务器中档        34    1808972.00      66  0.018297
#                41    1771788.00      76  0.017921
# 塔式服务器高档        81    1520894.00      48  0.015383
# 机架式服务器中、低档     100   1941475.86      72  0.019637
#                94    1711520.00      69  0.017311
#                90    1540762.00      62  0.015584
#                105   1539585.00      56  0.015572
# 机架式服务器高档       118   7866640.00      79  0.079567
#                125   6981569.00      36  0.070615
#                123   5212970.65      56  0.052727
#                126   3541433.00      66  0.035820
#                120   3166896.50      41  0.032032
#                128   2262878.00      39  0.022888

# %%
prop_0015.to_csv('./result/prop>=0.015.csv' , index_col= None)

# %% [markdown]
# # 3.group by month

# %%
def get_month(date):
    return date.split('-')[0] + '-' + date.split('-')[1]

# %%
China['month'] = China['date'].apply(get_month)

# %%
months = China.groupby('month', as_index=False).total_price.sum()

# %%
months
# Out:
#      month  total_price
# 0  2016-01   1278425.12
# 1  2016-02    952638.67
# 2  2016-03   6125751.34
# 3  2016-04   9624323.57
# 4  2016-05  20878438.28
# 5  2016-06  23225519.82
# 6  2016-07  21736054.48
# 7  2016-08  15046602.28

# %%
months.to_csv('./result/group_by_months.csv')
